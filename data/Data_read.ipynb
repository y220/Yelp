# %%
import pandas as pd
import nltk
import numpy as np

# %%
review = pd.read_json('review_city.json',lines = True)
review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  LG2ZaYiOgpr2DK_90pYjNw  V34qejxNsCbcgD8C0HVk-Q  HQl28KMwrEKHqhFrrDqVNQ
# 1  qWHp2l2lysENZObh6MAulA  5lb0POg2t-AkMFx6603cYQ  ZlCSsWS07JulSBIQlrbF5w
# 2  Ne_2CSfcKIqXHmv_KC0uqg  6sJN_HlM_uwpfLJ1puf1Fg  oVuZtlCFg_zF090Nhtp0Ow
# 3  2mLlQ9n5Ln_fykOuX_b0-A  EZ6g9a17UdMjtR-wrZebmA  wSAGILK2CFbq5BVZ5D67-A
# 4  Ymb8ZYPg2e8dvqhdj3Gkqw  hHFSpKcnDtJOs6M-JKFZ8Q  oCvxJBOs-Mbg-4oanPO7lQ
#
#    stars  useful  funny  cool  \
# 0      5       1      0     0
# 1      5       1      0     0
# 2      4       3      0     1
# 3      3       0      0     0
# 4      4       0      0     0
#
#                                                 text                date
# 0  I love Deagan's. I do. I really do. The atmosp... 2015-12-05 03:18:11
# 1  Called for a 5:15 morning reservation. The dri... 2015-05-26 10:36:47
# 2  A close friend was in town and so instead of t... 2018-02-01 19:15:00
# ...

# %%
review.shape
review.columns.values.tolist()
# Out:
# ['review_id',
#  'user_id',
#  'business_id',
#  'stars',
#  'useful',
#  'funny',
#  'cool',
#  'text',
#  'date']

# %%
business = pd.read_json('business_city.json',lines = True)
business.head()
# Out:
#               business_id                          name  \
# 0  pQeaRpvuhoEqudo3uymHIQ           The Empanadas House
# 1  7Dv4_HAxsxvadEsT5fxQBg   Dependable Brakes & Exhaust
# 2  M_guz7Dj7hX0evS672wIwA    Chocolate Shoppe Ice Cream
# 3  03x6ZlJ7s39DHqfTJU1Ecg        Beechmont Country Club
# 4  _4Oe9V-qTpU5iemM9bphlA  Goodyear Auto Service Center
#
#                          address        city state postal_code   latitude  \
# 0                 404 E Green St   Champaign    IL       61820  40.110446
# 1         1110 Saw Mill Run Blvd  Pittsburgh    PA       15226  40.406667
# 2              2831 Parmenter St   Middleton    WI       53562  43.105310
# 3             29600 Chagrin Blvd   Beachwood    OH       44122  41.461448
# 4  800 Fort Duquesne Blvd, Ste 1  Pittsburgh    PA       15222  40.444614
#
#    longitude  stars  review_count  is_open  \
# 0 -88.233073    4.5             5        1
# 1 -80.004450    5.0             5        1
# 2 -89.510142    3.5             6        1
# ...

# %%
business.shape
# Out:
# (36327, 14)

# %%
business.dropna(axis=0, how='any', subset = ['categories'], inplace=True)
business.shape
# Out:
# (36232, 14)

# %%
business=business.reset_index(drop=True)

# %%
text = list(business.categories)
len(text)
# Out:
# 36232

# %%
text = [a.lower() for a in text if isinstance(a,str)]

# %%
a = [i for i in range(0,len(text)) if text[i].find(' pet')==-1 ]

# %%
len(a)
# Out:
# 35376

# %%
a[35370:]
# Out:
# [36226, 36227, 36228, 36229, 36230, 36231]

# %%
business.categories[36118]
# Out:
# 'Dog Parks, Parks, Pets, Active Life'

# %%
pet=business.drop(labels=a,axis=0)

# %%
pet.tail()
# Out:
#                   business_id                        name  \
# 35975  gzAuoCpmFTaPUS4vystADQ         Mobile Vet Services
# 36025  VI5HAnxzRhW2jWKnLTLoew     Rufus DuMonde Pet Salon
# 36108  vm0SESMTXZAKQko1-Yq1Sw  Norwin Veterinary Hospital
# 36118  g-2x3EOwRYMezkSS_lIdxw      Bow Wow Beach Dog Park
# 36181  _43kPI_g4tqbH-AIET7z3g                The Poo Pros
#
#                          address              city state postal_code  \
# 35975           15058 Old Oak Dr      Strongsville    OH       44149
# 36025          600 Williamson St           Madison    WI       53703
# 36108               12411 Rte 30  North Huntington    PA       15642
# 36118               5027 Stow Rd              Stow    OH       44224
# 36181  7575 Tyler Blvd, Unit C47            Mentor    OH       44060
#
#         latitude  longitude  stars  review_count  is_open  \
# 35975  41.306080 -81.861045    5.0             4        1
# 36025  43.076701 -89.374957    4.0            21        1
# ...

# %%
pet=pet.reset_index(drop=True)

# %%
pet_raw = pd.merge(pet, review, how='left', on='business_id')

# %%
pet_raw.shape
# Out:
# (8978, 22)

# %%
pet = pet_raw.drop(columns=['address','postal_code','latitude','longitude','hours','review_id','date','city','state'])

# %%
pet
# Out:
#                  business_id                    name  stars_x  review_count  \
# 0     UyZqOcWxShRRtACCkZFkpQ               Local Pet      5.0             3
# 1     UyZqOcWxShRRtACCkZFkpQ               Local Pet      5.0             3
# 2     UyZqOcWxShRRtACCkZFkpQ               Local Pet      5.0             3
# 3     fhTTP5HRqOzmFw-31Qe7QA       Mario's Fish Bowl      2.0             4
# 4     fhTTP5HRqOzmFw-31Qe7QA       Mario's Fish Bowl      2.0             4
# ...                      ...                     ...      ...           ...
# 8973  g-2x3EOwRYMezkSS_lIdxw  Bow Wow Beach Dog Park      4.0            43
# 8974  g-2x3EOwRYMezkSS_lIdxw  Bow Wow Beach Dog Park      4.0            43
# 8975  _43kPI_g4tqbH-AIET7z3g            The Poo Pros      3.5             3
# 8976  _43kPI_g4tqbH-AIET7z3g            The Poo Pros      3.5             3
# 8977  _43kPI_g4tqbH-AIET7z3g            The Poo Pros      3.5             3
#
# ...
